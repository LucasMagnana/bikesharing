# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %%
# %run main.py --path ../ --num-samples 90000
# Out:
# start: 18:59:58.622669
# 1/4: 19:14:24.856547
# 1/4: 19:29:35.194467
# 1/4: 19:45:01.552693
# Random: 1.5892420537897312 %
# Good predict: 95.59902200488997 %
# Saving network...

# %% [markdown]
# # Bikepath fusion v2

# %%
# %run main.py --path ../ --num-samples 115000
# Out:
# start: 16:24:31.066343
# 1/4: 16:42:52.253121
# 1/4: 17:01:46.726720
# 1/4: 17:20:22.213212
# Random: 1.466992665036675 %
# Good predict: 96.08801955990221 %
# Saving network...

# %%
# %run main.py --path ../ --percentage-test 30
# Out:
# start: 11:10:24.539773
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/bikesharing/python/main.py in <module>
#     158     parse.add_argument('--percentage-test', type=int, default=0, help='percentage of data to use as testing')
#     159
# --> 160     main(parse.parse_args())
#
# ~/bikesharing/python/main.py in main(args)
#     102     loss = nn.NLLLoss()
#     103
# --> 104     tab_loss = learning.train(df_train, tab_clusters, loss, optimizer, network, size_data, cuda, args.num_samples)
#     105
#     106
#
# ~/bikesharing/python/learning.py in train(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step)
#     149 def train(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step):
#     150     if(isinstance(network, RNN) or isinstance(network, RNN_LSTM)):
# --> 151         return train_recursive(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step)
#     152     else:
#     153         return train_full_connected(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step)
#
# ~/bikesharing/python/learning.py in train_recursive(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step)
#     103         l = loss(output, target)
#     104         loss_tab.append(l.item())
# --> 105         l.backward()
#     106         optimizer.step()
#     107         '''for p in network.parameters():
#
# ~/.local/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/.local/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
